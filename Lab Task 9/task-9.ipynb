# %% [markdown]
# # AI-Lab: 09
# ### Rollnumber: BSAIM-F24-195
# ### Name: Aman Ali

# %% [markdown]
# <div class="alert alert-block alert-success">
#     Import <b>Libraries</b>
# </div>

# %%
import pandas as pd

# %% [markdown]
# <div class="alert alert-block alert-info">
#     1. <b>Data Gathering</b>
#     <br>
#     2. <b>Data Loading</b>
# </div>

# %%
df = pd.read_excel("data.xlsx")
df
# Out:
#      StudentID  Gender   Age  StudyHoursPerWeek  AttendanceRate   GPA  \
# 0          1.0    Male  24.0               37.0           90.75  3.47
# 1          2.0  Female  22.0               37.0           74.90  2.32
# 2          3.0    Male  22.0               10.0           53.36  2.38
# 3          4.0    Male  24.0               10.0           70.26  3.46
# 4          5.0    Male  18.0               19.0           74.87  2.31
# ..         ...     ...   ...                ...             ...   ...
# 495      496.0    Male  22.0               37.0           76.61  2.97
# 496      497.0    Male  23.0               11.0           56.29  3.20
# 497      498.0  Female  20.0                6.0           56.64  3.20
# 498      499.0    Male  22.0               18.0           57.18  2.05
# 499      500.0  Female  24.0               21.0           96.99  2.64
#
#            Major PartTimeJob ExtraCurricularActivities
# 0           Arts         Yes                        No
# 1      Education          No                        No
# 2       Business          No                        No
# 3        Science         Yes                        No
# 4      Education         Yes                        No
# ..           ...         ...                       ...
# 495      Science          No                        No
# 496      Science          No                        No
# 497      Science          No                       Yes
# 498     Business          No                       Yes
# 499  Engineering          No                        No
#
# [500 rows x 9 columns]

# %% [markdown]
# <div class="alert alert-block alert-info">
#     3. <b>Data Exploration</b>
# </div>

# %%
df.head()
# Out:
#    StudentID  Gender   Age  StudyHoursPerWeek  AttendanceRate   GPA  \
# 0        1.0    Male  24.0               37.0           90.75  3.47
# 1        2.0  Female  22.0               37.0           74.90  2.32
# 2        3.0    Male  22.0               10.0           53.36  2.38
# 3        4.0    Male  24.0               10.0           70.26  3.46
# 4        5.0    Male  18.0               19.0           74.87  2.31
#
#        Major PartTimeJob ExtraCurricularActivities
# 0       Arts         Yes                        No
# 1  Education          No                        No
# 2   Business          No                        No
# 3    Science         Yes                        No
# 4  Education         Yes                        No

# %%
df.tail()
# Out:
#      StudentID  Gender   Age  StudyHoursPerWeek  AttendanceRate   GPA  \
# 495      496.0    Male  22.0               37.0           76.61  2.97
# 496      497.0    Male  23.0               11.0           56.29  3.20
# 497      498.0  Female  20.0                6.0           56.64  3.20
# 498      499.0    Male  22.0               18.0           57.18  2.05
# 499      500.0  Female  24.0               21.0           96.99  2.64
#
#            Major PartTimeJob ExtraCurricularActivities
# 495      Science          No                        No
# 496      Science          No                        No
# 497      Science          No                       Yes
# 498     Business          No                       Yes
# 499  Engineering          No                        No

# %%
df.columns
# Out:
# Index(['StudentID', 'Gender', 'Age', 'StudyHoursPerWeek', 'AttendanceRate',
#        'GPA', 'Major', 'PartTimeJob', 'ExtraCurricularActivities'],
#       dtype='object')

# %%
df.count()
# Out:
# StudentID                    499
# Gender                       460
# Age                          460
# StudyHoursPerWeek            460
# AttendanceRate               460
# GPA                          500
# Major                        478
# PartTimeJob                  478
# ExtraCurricularActivities    478
# dtype: int64

# %%
df.describe()
# Out:
#         StudentID         Age  StudyHoursPerWeek  AttendanceRate        GPA
# count  499.000000  460.000000         460.000000      460.000000  500.00000
# mean   250.801603   20.960870          19.782609       74.830217    2.98516
# std    144.469180    1.995253          11.539669       14.725526    0.56362
# min      1.000000   18.000000           1.000000       50.010000    2.00000
# 25%    126.500000   19.000000           9.750000       62.177500    2.48750
# 50%    251.000000   21.000000          20.000000       75.070000    3.00000
# 75%    375.500000   23.000000          30.000000       87.220000    3.48000
# max    500.000000   24.000000          39.000000       99.970000    3.99000

# %%
df.describe(include='all')
# Out:
#          StudentID  Gender         Age  StudyHoursPerWeek  AttendanceRate  \
# count   499.000000     460  460.000000         460.000000      460.000000
# unique         NaN       2         NaN                NaN             NaN
# top            NaN  Female         NaN                NaN             NaN
# freq           NaN     233         NaN                NaN             NaN
# mean    250.801603     NaN   20.960870          19.782609       74.830217
# std     144.469180     NaN    1.995253          11.539669       14.725526
# min       1.000000     NaN   18.000000           1.000000       50.010000
# 25%     126.500000     NaN   19.000000           9.750000       62.177500
# 50%     251.000000     NaN   21.000000          20.000000       75.070000
# 75%     375.500000     NaN   23.000000          30.000000       87.220000
# max     500.000000     NaN   24.000000          39.000000       99.970000
#
#               GPA     Major PartTimeJob ExtraCurricularActivities
# count   500.00000       478         478                       478
# unique        NaN         5           2                         2
# top           NaN  Business         Yes                        No
# freq          NaN       111         255                       250
# mean      2.98516       NaN         NaN                       NaN
# std       0.56362       NaN         NaN                       NaN
# min       2.00000       NaN         NaN                       NaN
# 25%       2.48750       NaN         NaN                       NaN
# 50%       3.00000       NaN         NaN                       NaN
# 75%       3.48000       NaN         NaN                       NaN
# max       3.99000       NaN         NaN                       NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   StudentID                  499 non-null    float64
#  1   Gender                     460 non-null    object
#  2   Age                        460 non-null    float64
#  3   StudyHoursPerWeek          460 non-null    float64
#  4   AttendanceRate             460 non-null    float64
#  5   GPA                        500 non-null    float64
#  6   Major                      478 non-null    object
#  7   PartTimeJob                478 non-null    object
#  8   ExtraCurricularActivities  478 non-null    object
# dtypes: float64(5), object(4)
# memory usage: 35.3+ KB

# %%
print('rows: ', df.shape[0]) 
print('columns: ', df.shape[1])
# Out:
# rows:  500
# columns:  9

# %%
df.isnull().sum()
# Out:
# StudentID                     1
# Gender                       40
# Age                          40
# StudyHoursPerWeek            40
# AttendanceRate               40
# GPA                           0
# Major                        22
# PartTimeJob                  22
# ExtraCurricularActivities    22
# dtype: int64

# %%
df.nunique()
# Out:
# StudentID                    499
# Gender                         2
# Age                            7
# StudyHoursPerWeek             39
# AttendanceRate               440
# GPA                          184
# Major                          5
# PartTimeJob                    2
# ExtraCurricularActivities      2
# dtype: int64

# %%
def mean_col(col):
    return df[col].mean()

def median_col(col):
    return df[col].median()

def mod_col(col):
    return df[col].mode()[0]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   StudentID                  499 non-null    float64
#  1   Gender                     460 non-null    object
#  2   Age                        460 non-null    float64
#  3   StudyHoursPerWeek          460 non-null    float64
#  4   AttendanceRate             460 non-null    float64
#  5   GPA                        500 non-null    float64
#  6   Major                      478 non-null    object
#  7   PartTimeJob                478 non-null    object
#  8   ExtraCurricularActivities  478 non-null    object
# dtypes: float64(5), object(4)
# memory usage: 35.3+ KB

# %%
print("Mean of Age is  : ", mean_col("Age"))
print("Mode of Major is  : ", mod_col("Major"))
# Out:
# Mean of Age is  :  20.96086956521739
# Mode of Major is  :  Business

# %%
df.dtypes
# Out:
# StudentID                    float64
# Gender                        object
# Age                          float64
# StudyHoursPerWeek            float64
# AttendanceRate               float64
# GPA                          float64
# Major                         object
# PartTimeJob                   object
# ExtraCurricularActivities     object
# dtype: object
